# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# # Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1
    
#     # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | viedma
# Processing Record 2 of Set 1 | tara
# Processing Record 3 of Set 1 | mokhsogollokh
# Processing Record 4 of Set 1 | bonthe
# Processing Record 5 of Set 1 | marienburg
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | gemena
# Processing Record 8 of Set 1 | harper
# Processing Record 9 of Set 1 | kalach-na-donu
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | nuuk
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | leh
# Processing Record 14 of Set 1 | ibaiti
# Processing Record 15 of Set 1 | praia da vitoria
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | arlit
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | vao
# Processing Record 31 of Set 1 | luganville
# Processing Record 32 of Set 1 | pochutla
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | panguipulli
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | volax
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | hoshangabad
# Processing Record 40 of Set 1 | birao
# Processing Record 41 of Set 1 | morondava
# Processing Record 42 of Set 1 | florianopolis
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | wajir
# Processing Record 46 of Set 1 | phitsanulok
# Processing Record 47 of Set 1 | lugovskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | ambon
# Processing Record 5 of Set 2 | del rio
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | mont-dore
# Processing Record 8 of Set 2 | kamenka
# Processing Record 9 of Set 2 | fukue
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | ahipara
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | puerto baquerizo moreno
# Processing Record 14 of Set 2 | les cayes
# Processing Record 15 of Set 2 | saint-francois
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | namibe
# Processing Record 21 of Set 2 | avera
# Processing Record 22 of Set 2 | navahrudak
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | san calixto
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | fort nelson
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | sharjah
# Processing Record 35 of Set 2 | nantucket
# Processing Record 36 of Set 2 | smithers
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | olinda
# Processing Record 39 of Set 2 | imeni poliny osipenko
# City not found. Skipping...
# Processing Record 40 of Set 2 | bereda
# Processing Record 41 of Set 2 | wilmington island
# Processing Record 42 of Set 2 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 43 of Set 2 | tucupita
# Processing Record 44 of Set 2 | pangnirtung
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | sur
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | bandarbeyla
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 3 | alta floresta
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | pontes e lacerda
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | san quintin
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | payo
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | agutaya
# Processing Record 13 of Set 3 | atambua
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | melfi
# Processing Record 18 of Set 3 | kurilsk
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | carora
# Processing Record 22 of Set 3 | acari
# Processing Record 23 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 3 | bucerias
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | salumbar
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | camopi
# Processing Record 29 of Set 3 | arrah
# Processing Record 30 of Set 3 | skhisma
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | the valley
# Processing Record 38 of Set 3 | kipushi
# Processing Record 39 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 3 | teya
# Processing Record 41 of Set 3 | atuona
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | pretoria
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | santos reyes nopala
# Processing Record 46 of Set 3 | saint-pierre
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | roebourne
# Processing Record 3 of Set 4 | kailua
# Processing Record 4 of Set 4 | berlevag
# Processing Record 5 of Set 4 | flinders
# Processing Record 6 of Set 4 | tiznit
# Processing Record 7 of Set 4 | tazovskiy
# Processing Record 8 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | langham
# Processing Record 12 of Set 4 | ler
# Processing Record 13 of Set 4 | launceston
# Processing Record 14 of Set 4 | yar-sale
# Processing Record 15 of Set 4 | allacapan
# Processing Record 16 of Set 4 | ye
# City not found. Skipping...
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | belmonte
# Processing Record 19 of Set 4 | benjamin hill
# Processing Record 20 of Set 4 | chokwe
# Processing Record 21 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 4 | naze
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | otjimbingwe
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | yarmouth
# Processing Record 27 of Set 4 | antofagasta
# Processing Record 28 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 4 | plettenberg bay
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | manica
# Processing Record 32 of Set 4 | ostrow wielkopolski
# Processing Record 33 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 4 | dargaville
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | kangaatsiaq
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | santa maria
# Processing Record 40 of Set 4 | davila
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | san pedro
# Processing Record 43 of Set 4 | nishihara
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | bawku
# Processing Record 49 of Set 4 | gavrilov posad
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 5 | coquimbo
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | san antonio
# Processing Record 4 of Set 5 | abha
# Processing Record 5 of Set 5 | piranshahr
# Processing Record 6 of Set 5 | inhambane
# Processing Record 7 of Set 5 | walvis bay
# Processing Record 8 of Set 5 | almeirim
# Processing Record 9 of Set 5 | mahibadhoo
# Processing Record 10 of Set 5 | aras
# Processing Record 11 of Set 5 | solwezi
# Processing Record 12 of Set 5 | adamas
# Processing Record 13 of Set 5 | loviisa
# Processing Record 14 of Set 5 | lakota
# Processing Record 15 of Set 5 | itainopolis
# Processing Record 16 of Set 5 | coahuayana
# Processing Record 17 of Set 5 | kathmandu
# Processing Record 18 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 5 | san patricio
# Processing Record 20 of Set 5 | alberdi
# Processing Record 21 of Set 5 | broome
# Processing Record 22 of Set 5 | lata
# Processing Record 23 of Set 5 | byron bay
# Processing Record 24 of Set 5 | port lincoln
# Processing Record 25 of Set 5 | castro
# Processing Record 26 of Set 5 | dajabon
# Processing Record 27 of Set 5 | srednekolymsk
# Processing Record 28 of Set 5 | tombouctou
# Processing Record 29 of Set 5 | denpasar
# Processing Record 30 of Set 5 | cardoso
# Processing Record 31 of Set 5 | mezen
# Processing Record 32 of Set 5 | sergeyevka
# Processing Record 33 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 5 | ust-omchug
# Processing Record 35 of Set 5 | jinxiang
# Processing Record 36 of Set 5 | dingle
# Processing Record 37 of Set 5 | hambantota
# Processing Record 38 of Set 5 | xining
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | saint-georges
# Processing Record 41 of Set 5 | svetlyy
# Processing Record 42 of Set 5 | palmerston
# Processing Record 43 of Set 5 | yulara
# Processing Record 44 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 5 | girvan
# Processing Record 46 of Set 5 | pilar de la horadada
# Processing Record 47 of Set 5 | dwarka
# Processing Record 48 of Set 5 | khani
# Processing Record 49 of Set 5 | sabang
# Processing Record 50 of Set 5 | shelton
# Processing Record 1 of Set 6 | batemans bay
# Processing Record 2 of Set 6 | hailey
# Processing Record 3 of Set 6 | santa fe do sul
# Processing Record 4 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 6 | katherine
# Processing Record 6 of Set 6 | eureka
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 6 | aitape
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | sabha
# Processing Record 12 of Set 6 | vanimo
# Processing Record 13 of Set 6 | hearst
# Processing Record 14 of Set 6 | songea
# Processing Record 15 of Set 6 | revelstoke
# Processing Record 16 of Set 6 | bacolod
# Processing Record 17 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 6 | lazaro cardenas
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | tecpan
# Processing Record 22 of Set 6 | nicolas bravo
# Processing Record 23 of Set 6 | kloulklubed
# Processing Record 24 of Set 6 | mahajanga
# Processing Record 25 of Set 6 | hojai
# Processing Record 26 of Set 6 | yarada
# Processing Record 27 of Set 6 | usinsk
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | geraldton
# Processing Record 30 of Set 6 | los llanos de aridane
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | stromness
# Processing Record 33 of Set 6 | kirensk
# Processing Record 34 of Set 6 | kavieng
# Processing Record 35 of Set 6 | minervino murge
# Processing Record 36 of Set 6 | dunedin
# Processing Record 37 of Set 6 | cabedelo
# Processing Record 38 of Set 6 | rorvik
# Processing Record 39 of Set 6 | chalus
# Processing Record 40 of Set 6 | stornoway
# Processing Record 41 of Set 6 | yerbogachen
# Processing Record 42 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 6 | zambezi
# Processing Record 44 of Set 6 | derzhavinsk
# Processing Record 45 of Set 6 | port elizabeth
# Processing Record 46 of Set 6 | bani walid
# Processing Record 47 of Set 6 | kaeo
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | agadez
# Processing Record 50 of Set 6 | presidencia roque saenz pena
# Processing Record 1 of Set 7 | ola
# Processing Record 2 of Set 7 | sioux lookout
# Processing Record 3 of Set 7 | raudeberg
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | acarau
# Processing Record 6 of Set 7 | astoria
# Processing Record 7 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 7 | codrington
# Processing Record 9 of Set 7 | manaure
# Processing Record 10 of Set 7 | sandomierz
# Processing Record 11 of Set 7 | gisborne
# Processing Record 12 of Set 7 | ucluelet
# Processing Record 13 of Set 7 | nicoya
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | khilok
# Processing Record 16 of Set 7 | chake chake
# Processing Record 17 of Set 7 | skerries
# Processing Record 18 of Set 7 | goderich
# Processing Record 19 of Set 7 | mahebourg
# Processing Record 20 of Set 7 | kulhudhuffushi
# Processing Record 21 of Set 7 | sao gabriel
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | muli
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | nouadhibou
# Processing Record 26 of Set 7 | colares
# Processing Record 27 of Set 7 | stutterheim
# Processing Record 28 of Set 7 | bull savanna
# Processing Record 29 of Set 7 | narragansett
# Processing Record 30 of Set 7 | benguela
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | comodoro rivadavia
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | savannah bight
# Processing Record 35 of Set 7 | marystown
# Processing Record 36 of Set 7 | rio gallegos
# Processing Record 37 of Set 7 | khandyga
# Processing Record 38 of Set 7 | gwadar
# Processing Record 39 of Set 7 | bulgan
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 7 | nanortalik
# Processing Record 43 of Set 7 | vero beach
# Processing Record 44 of Set 7 | krasnoselkup
# Processing Record 45 of Set 7 | kishni
# Processing Record 46 of Set 7 | jacqueville
# Processing Record 47 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 7 | cololaca
# Processing Record 50 of Set 7 | emerald
# Processing Record 1 of Set 8 | salalah
# Processing Record 2 of Set 8 | abu kamal
# Processing Record 3 of Set 8 | osakarovka
# Processing Record 4 of Set 8 | malartic
# Processing Record 5 of Set 8 | malko tarnovo
# Processing Record 6 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 8 | san rafael
# Processing Record 9 of Set 8 | sinop
# Processing Record 10 of Set 8 | russell
# Processing Record 11 of Set 8 | anderson
# Processing Record 12 of Set 8 | bow island
# Processing Record 13 of Set 8 | necochea
# Processing Record 14 of Set 8 | ewa beach
# Processing Record 15 of Set 8 | finschhafen
# Processing Record 16 of Set 8 | okhotsk
# Processing Record 17 of Set 8 | salihorsk
# Processing Record 18 of Set 8 | alegrete
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | rio grande
# Processing Record 21 of Set 8 | noboribetsu
# Processing Record 22 of Set 8 | coihaique
# Processing Record 23 of Set 8 | alofi
# Processing Record 24 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | kollam
# Processing Record 26 of Set 8 | tonj
# Processing Record 27 of Set 8 | khatanga
# Processing Record 28 of Set 8 | port hedland
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | axim
# Processing Record 31 of Set 8 | horta
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | saint-augustin
# Processing Record 34 of Set 8 | lodja
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | leningradskiy
# Processing Record 37 of Set 8 | gondanglegi
# Processing Record 38 of Set 8 | neuquen
# Processing Record 39 of Set 8 | concepcion del uruguay
# Processing Record 40 of Set 8 | bozoum
# Processing Record 41 of Set 8 | cayenne
# Processing Record 42 of Set 8 | luau
# Processing Record 43 of Set 8 | nyzhni sirohozy
# Processing Record 44 of Set 8 | esperance
# Processing Record 45 of Set 8 | tura
# Processing Record 46 of Set 8 | hovd
# Processing Record 47 of Set 8 | stargard szczecinski
# Processing Record 48 of Set 8 | mandalgovi
# Processing Record 49 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 8 | port-gentil
# Processing Record 1 of Set 9 | lasa
# Processing Record 2 of Set 9 | hundorp
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | emba
# Processing Record 5 of Set 9 | oktyabrskiy
# Processing Record 6 of Set 9 | amahai
# Processing Record 7 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 9 | jiazi
# Processing Record 9 of Set 9 | cairns
# Processing Record 10 of Set 9 | yuzhno-kurilsk
# Processing Record 11 of Set 9 | fare
# Processing Record 12 of Set 9 | pitkyaranta
# Processing Record 13 of Set 9 | grand gaube
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | ilinge
# Processing Record 16 of Set 9 | thinadhoo
# Processing Record 17 of Set 9 | svetlogorsk
# Processing Record 18 of Set 9 | north bend
# Processing Record 19 of Set 9 | moa
# Processing Record 20 of Set 9 | ilulissat
# Processing Record 21 of Set 9 | masindi
# Processing Record 22 of Set 9 | laguna
# Processing Record 23 of Set 9 | repalle
# Processing Record 24 of Set 9 | cap malheureux
# Processing Record 25 of Set 9 | gerash
# Processing Record 26 of Set 9 | mogadishu
# Processing Record 27 of Set 9 | zyryanka
# Processing Record 28 of Set 9 | pisco
# Processing Record 29 of Set 9 | houma
# Processing Record 30 of Set 9 | skibbereen
# Processing Record 31 of Set 9 | zachary
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | kirakira
# Processing Record 34 of Set 9 | aasiaat
# Processing Record 35 of Set 9 | tayturka
# Processing Record 36 of Set 9 | alyangula
# Processing Record 37 of Set 9 | nemuro
# Processing Record 38 of Set 9 | orizona
# Processing Record 39 of Set 9 | okha
# Processing Record 40 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 9 | itapirapua
# Processing Record 43 of Set 9 | kalmunai
# Processing Record 44 of Set 9 | baghdad
# Processing Record 45 of Set 9 | ascension
# Processing Record 46 of Set 9 | chuy
# Processing Record 47 of Set 9 | victor harbor
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | sorland
# Processing Record 50 of Set 9 | lufilufi
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | tessalit
# Processing Record 3 of Set 10 | seminole
# Processing Record 4 of Set 10 | chihuahua
# Processing Record 5 of Set 10 | vangaindrano
# Processing Record 6 of Set 10 | nador
# Processing Record 7 of Set 10 | sabalgarh
# Processing Record 8 of Set 10 | bubaque
# Processing Record 9 of Set 10 | svetlaya
# Processing Record 10 of Set 10 | sisimiut
# Processing Record 11 of Set 10 | huanren
# Processing Record 12 of Set 10 | bizhbulyak
# Processing Record 13 of Set 10 | bontang
# Processing Record 14 of Set 10 | lethem
# Processing Record 15 of Set 10 | moyale
# Processing Record 16 of Set 10 | sulangan
# Processing Record 17 of Set 10 | kidal
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | vostok
# Processing Record 20 of Set 10 | sakakah
# Processing Record 21 of Set 10 | dhidhdhoo
# Processing Record 22 of Set 10 | dandong
# Processing Record 23 of Set 10 | baie-comeau
# Processing Record 24 of Set 10 | nome
# Processing Record 25 of Set 10 | lahij
# Processing Record 26 of Set 10 | picui
# Processing Record 27 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | tonantins
# Processing Record 29 of Set 10 | sokolo
# Processing Record 30 of Set 10 | shadegan
# Processing Record 31 of Set 10 | vizinga
# Processing Record 32 of Set 10 | beringovskiy
# Processing Record 33 of Set 10 | putla
# City not found. Skipping...
# Processing Record 34 of Set 10 | tshikapa
# Processing Record 35 of Set 10 | brownwood
# Processing Record 36 of Set 10 | san cristobal
# Processing Record 37 of Set 10 | merauke
# Processing Record 38 of Set 10 | saint george
# Processing Record 39 of Set 10 | asau
# Processing Record 40 of Set 10 | gushikawa
# Processing Record 41 of Set 10 | karaton
# Processing Record 42 of Set 10 | fot
# Processing Record 43 of Set 10 | euclid
# Processing Record 44 of Set 10 | shingu
# Processing Record 45 of Set 10 | pudozh
# Processing Record 46 of Set 10 | marquette
# Processing Record 47 of Set 10 | tianpeng
# Processing Record 48 of Set 10 | senador guiomard
# Processing Record 49 of Set 10 | lensk
# Processing Record 50 of Set 10 | golspie
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | saint-leu
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | port hardy
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | anadyr
# Processing Record 7 of Set 11 | cururupu
# Processing Record 8 of Set 11 | olafsvik
# Processing Record 9 of Set 11 | diamantino
# Processing Record 10 of Set 11 | lixourion
# Processing Record 11 of Set 11 | benjamin constant
# Processing Record 12 of Set 11 | kamina
# Processing Record 13 of Set 11 | amuntai
# Processing Record 14 of Set 11 | birzai
# Processing Record 15 of Set 11 | klaksvik
# Processing Record 16 of Set 11 | mujiayingzi
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | nenjiang
# Processing Record 19 of Set 11 | san ramon
# Processing Record 20 of Set 11 | milkovo
# Processing Record 21 of Set 11 | marsh harbour
# Processing Record 22 of Set 11 | port macquarie
# Processing Record 23 of Set 11 | kruisfontein
# Processing Record 24 of Set 11 | isangel
# Processing Record 25 of Set 11 | alencon
# Processing Record 26 of Set 11 | gat
# Processing Record 27 of Set 11 | awbari
# Processing Record 28 of Set 11 | novyy urgal
# Processing Record 29 of Set 11 | surin
# Processing Record 30 of Set 11 | mayor pablo lagerenza
# Processing Record 31 of Set 11 | nuevo emperador
# Processing Record 32 of Set 11 | salto
# Processing Record 33 of Set 11 | karasjok
# Processing Record 34 of Set 11 | herat
# Processing Record 35 of Set 11 | inuvik
# Processing Record 36 of Set 11 | tomiya
# Processing Record 37 of Set 11 | odoyev
# Processing Record 38 of Set 11 | firozpur
# Processing Record 39 of Set 11 | ulaanbaatar
# Processing Record 40 of Set 11 | talnakh
# Processing Record 41 of Set 11 | abay
# Processing Record 42 of Set 11 | zafra
# Processing Record 43 of Set 11 | aksu
# Processing Record 44 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 11 | fomboni
# Processing Record 46 of Set 11 | arkhipo-osipovka
# Processing Record 47 of Set 11 | werda
# Processing Record 48 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 11 | staryy nadym
# Processing Record 50 of Set 11 | keti bandar
# Processing Record 1 of Set 12 | lagoa
# Processing Record 2 of Set 12 | vila velha
# Processing Record 3 of Set 12 | korneuburg
# Processing Record 4 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 12 | ergani
# Processing Record 6 of Set 12 | vaitape
# Processing Record 7 of Set 12 | roald
# Processing Record 8 of Set 12 | chulman
# Processing Record 9 of Set 12 | billings
# Processing Record 10 of Set 12 | rostovka
# Processing Record 11 of Set 12 | noumea
# Processing Record 12 of Set 12 | pacific grove
# Processing Record 13 of Set 12 | itaquyry
# Processing Record 14 of Set 12 | ta khmau
# Processing Record 15 of Set 12 | bintulu
# Processing Record 16 of Set 12 | murliganj
# Processing Record 17 of Set 12 | kargasok
# Processing Record 18 of Set 12 | dumas
# Processing Record 19 of Set 12 | jieshi
# Processing Record 20 of Set 12 | wabana
# Processing Record 21 of Set 12 | tabas
# Processing Record 22 of Set 12 | kabarnet
# Processing Record 23 of Set 12 | jabinyanah
# Processing Record 24 of Set 12 | yumen
# Processing Record 25 of Set 12 | jumla
# Processing Record 26 of Set 12 | maniitsoq
# Processing Record 27 of Set 12 | idil
# Processing Record 28 of Set 12 | vila
# Processing Record 29 of Set 12 | catia la mar
# Processing Record 30 of Set 12 | rudarpur
# Processing Record 31 of Set 12 | vidim
# Processing Record 32 of Set 12 | aktau
# Processing Record 33 of Set 12 | fort frances
# Processing Record 34 of Set 12 | padang
# Processing Record 35 of Set 12 | opuwo
# Processing Record 36 of Set 12 | bela
# Processing Record 37 of Set 12 | iskateley
# Processing Record 38 of Set 12 | skelleftea
# Processing Record 39 of Set 12 | zunyi
# Processing Record 40 of Set 12 | rocha
# Processing Record 41 of Set 12 | karratha
# Processing Record 42 of Set 12 | brae
# Processing Record 43 of Set 12 | bonnyville
# Processing Record 44 of Set 12 | waipawa
# Processing Record 45 of Set 12 | borovoy
# Processing Record 46 of Set 12 | dawlatabad
# Processing Record 47 of Set 12 | solnechnyy
# Processing Record 48 of Set 12 | tilichiki
# Processing Record 49 of Set 12 | scarborough
# Processing Record 50 of Set 12 | haines junction
# Processing Record 1 of Set 13 | ko samui
# Processing Record 2 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 13 | aklavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 557

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Viedma -40.8135  -62.9967     41.05        81          80
# 1            Tara  56.8944   74.3710     70.20        86         100
# 2   Mokhsogollokh  61.4681  128.9203     72.79        47           0
# 3          Bonthe   7.5264  -12.5050     76.35        84         100
# 4      Marienburg  54.0359   19.0266     64.96        76          91
# 5           Vaini -21.2000 -175.2000     78.96        94          20
# 6          Gemena   3.2500   19.7667     72.16        84          98
# 7          Harper   4.3750   -7.7169     75.43        73          91
# 8  Kalach-Na-Donu  48.6910   43.5264     69.12        56           4
# 9          Hobart -42.8794  147.3294     46.26        70          40
#
#    Wind Speed Country                 Date
# 0        4.88      AR  2021-07-25 00:51:56
# 1        3.85      RU  2021-07-25 00:51:56
# 2       11.03      RU  2021-07-25 00:51:57
# 3        8.30      SL  2021-07-25 00:51:57
# 4        4.72      PL  2021-07-25 00:51:58
# 5        5.75      TO  2021-07-25 00:51:58
# 6        1.59      CD  2021-07-25 00:51:58
# 7        5.53      LR  2021-07-25 00:51:59
# 8        6.91      RU  2021-07-25 00:51:59
# 9        5.99      AU  2021-07-25 00:51:59

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Viedma      AR  2021-07-25 00:51:56 -40.8135  -62.9967     41.05
# 1            Tara      RU  2021-07-25 00:51:56  56.8944   74.3710     70.20
# 2   Mokhsogollokh      RU  2021-07-25 00:51:57  61.4681  128.9203     72.79
# 3          Bonthe      SL  2021-07-25 00:51:57   7.5264  -12.5050     76.35
# 4      Marienburg      PL  2021-07-25 00:51:58  54.0359   19.0266     64.96
# 5           Vaini      TO  2021-07-25 00:51:58 -21.2000 -175.2000     78.96
# 6          Gemena      CD  2021-07-25 00:51:58   3.2500   19.7667     72.16
# 7          Harper      LR  2021-07-25 00:51:59   4.3750   -7.7169     75.43
# 8  Kalach-Na-Donu      RU  2021-07-25 00:51:59  48.6910   43.5264     69.12
# 9          Hobart      AU  2021-07-25 00:51:59 -42.8794  147.3294     46.26
#
#    Humidity  Cloudiness  Wind Speed
# 0        81          80        4.88
# 1        86         100        3.85
# 2        47           0       11.03
# 3        84         100        8.30
# 4        76          91        4.72
# 5        94          20        5.75
# 6        84          98        1.59
# 7        73          91        5.53
# 8        56           4        6.91
# 9        70          40        5.99

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
